# %% [markdown]
# # Italian COVID Library Tutorial
#
# Welcome to the Italian COVID Library tutorial, which shall guide you through the use of this library.
#
# ## Getting Started with Italian COVID Library
#
# Before starting, make sure you have installed Italian COVID Library as shown in README.md or the GitHub project homepage.
#
# Whenever you want to use Italian COVID Library in your code, just import it:

# %%
import itacovidlib.icl_functions as icl

# %% [markdown]
# You are now ready to use the full library.
# The library functions are divided into "getter" functions (the ones whose name starts with "get"), "teller" functions (name starting with "tell") and "map plotter" functions (plot_on_map and prepare_for_plotting_on_map).
#
# The following shows the full list of functions per category and in alphabetical order. The complete manual page for each function can be shown with one of these two options (for, as an example, tell_total_vaccinated):

# %%
help(icl.tell_total_vaccinated)
# Out:
# Help on function tell_total_vaccinated in module itacovidlib.icl_functions:
#
# tell_total_vaccinated(dose_number, option='n')
#     Depending on the int value provided as dose_number:
#     dose_number = 1: returns the number of individuals who have been injected at least one vaccine dose in Italy (independently of it being enough for vaccination cycle completion, as is the case with Janssen vaccine or for individuals with recent COVID-19 injection, for whom only one dose is required;
#     dose_number = 2: returns the number of individuals who have completed the vaccination cycle in Italy (with double dose for Pfizer/BioNTech, Moderna and Vaxzevria (AstraZeneca), with single dose for Janssen, with single dose for individuals previously infected with COVID-19 between 3 and 6 months before vaccination;
#     dose_number = 3: returns the number of individuals who have been injected an extra dose of vaccine in Italy, being eligible for it depending on their medical condition (commonly referred to as "third dose" in media).
#
#     Result is returned, depending on the str value provided as option:
#     no option or option = "n" or "number": just returns the requested number (default option);
#     option = "o" or "over12": returns the requested number as a fraction of the Italian population aged over 12;
#     option = "p" or "population": returns the requested number as a fraction of the whole Italian population.
#
#     Parameters
#     ----------
#     dose_number : int
#         Dose number of interest. See above for the meaning of dose_number = 1, 2 or 3. Other int values yield an error.
#
#     option : str
#         Output option. See above for the meaning of the various option codes. Other str values yield an error.
#
#     Raises
#     ------
#     ItaCovidLibConnectionError
#         Raised when there are issues with Internet connection.
#
#     ItaCovidLibArgumentError
#         Raised when improper arguments are passed to the function.
#
#     Returns
#     -------
#     FOR THE DEFAULT OPTION:
#     numpy.int64
#         NumPy integer (see above for its meaning, depending on dose_number code).
#
#     FOR THE OTHER OPTIONS:
#     numpy.float64
#         NumPy floating point (see above for its meaning, depending on dose_number code and option code).
#
#     See Also
#     --------
#     get_vaccine_admin : full data about vaccine administration in Italy

# %%
icl.tell_total_vaccinated?

# %% [markdown]
# ## Getter Functions ("get_")
#
# Getter functions are functions which retrieve directly **raw data** about COVID19 infections and vaccinations from the official governmental databases, making them available to the user in the form of **Pandas DataFrames**. The returned object can then be handled as any normal DataFrame with the instruments of the Pandas library.
# Some data (e.g. the amount of total vaccinated people) are not returned by Getter functions but by Teller functions (head to the Teller functions section to see why and how to get those data).

# %% [markdown]
# ### get_admin_sites
#
# Returns a DataFrame about COVID-19 vaccine administration points in Italy.

# %%
icl.get_admin_sites()
# Out:
#     region_code  province     municipality  \
# 0           ABR    CHIETI           CHIETI
# 1           ABR    CHIETI         LANCIANO
# 2           ABR    CHIETI            VASTO
# 3           ABR  L'AQUILA         AVEZZANO
# 4           ABR  L'AQUILA         L'AQUILA
# ..          ...       ...              ...
# 288         VEN    ROVIGO           ROVIGO
# 289         VEN   TREVISO  VITTORIO VENETO
# 290         VEN   VENEZIA   VENEZIA MESTRE
# 291         VEN    VERONA           VERONA
# 292         VEN   VICENZA          VICENZA
#
#                                                  place NUTS1_code NUTS2_code  \
# 0                   PRESIDIO OSPEDALIERO SS ANNUNZIATA        ITF       ITF1
# 1                        PRESIDIO OSPEDALIERO RENZETTI        ITF       ITF1
# 2                         PRESIDIO OSPEDALIERO SAN PIO        ITF       ITF1
# 3                            P.O. SS. FILIPPO E NICOLA        ITF       ITF1
# 4                   PRESIDIO OSPEDALIERO SAN SALVATORE        ITF       ITF1
# ..                                                 ...        ...        ...
# 288          OSPEDALE "SANTA MARIA DELLA MISERICORDIA"        ITH       ITH3
# 289                        OSPEDALE DI VITTORIO VENETO        ITH       ITH3
# 290                               OSPEDALE DELL'ANGELO        ITH       ITH3
# 291  AZIENDA OSPEDALIERA UNIVERSITARIA INTEGRATA DI...        ITH       ITH3
# 292                                OSPEDALE DI VICENZA        ITH       ITH3
#
#      ISTAT_region_code   region
# 0                   13  Abruzzo
# 1                   13  Abruzzo
# 2                   13  Abruzzo
# 3                   13  Abruzzo
# 4                   13  Abruzzo
# ..                 ...      ...
# 288                  5   Veneto
# 289                  5   Veneto
# 290                  5   Veneto
# 291                  5   Veneto
# 292                  5   Veneto
#
# [293 rows x 8 columns]

# %% [markdown]
# ### get_admin_sites_types
#
# Returns a DataFrame about the types of COVID-19 vaccine administration points in Italy.

# %%
icl.get_admin_sites_types()
# Out:
#      region_code                                              place  \
# 0            ABR           ASP1-TERAMO-CASA DI RIPOSO-DE BENEDICTIS
# 1            ABR                          AVEZZANO-SULMONA-L'AQUILA
# 2            ABR                            CASA DI CURA PIERANGELI
# 3            ABR                          CASA DI CURA VILLA SERENA
# 4            ABR                     CDC S.CAMILLA-C.RIA.VILLA PINI
# ...          ...                                                ...
# 2898         VEN                                      PSR MOBY DICK
# 2899         VEN               PSR NO PROBLEM COOP. STUDIO PROGETTO
# 2900         VEN  RES.ASS.TOSS. - COMUNITA' CONTATTO - CEIS DON ...
# 2901         VEN                  RES.ASS.TOSS.-CASA AURORA VENEZIA
# 2902         VEN               RSA "NOI CON VOI"  - MOGLIANO VENETO
#
#               type NUTS1_code NUTS2_code  ISTAT_region_code   region
# 0     Territoriale        ITF       ITF1                 13  Abruzzo
# 1      Ospedaliero        ITF       ITF1                 13  Abruzzo
# 2      Ospedaliero        ITF       ITF1                 13  Abruzzo
# 3      Ospedaliero        ITF       ITF1                 13  Abruzzo
# 4     Territoriale        ITF       ITF1                 13  Abruzzo
# ...            ...        ...        ...                ...      ...
# 2898  Territoriale        ITH       ITH3                  5   Veneto
# 2899  Territoriale        ITH       ITH3                  5   Veneto
# 2900  Territoriale        ITH       ITH3                  5   Veneto
# 2901  Territoriale        ITH       ITH3                  5   Veneto
# 2902  Territoriale        ITH       ITH3                  5   Veneto
#
# [2903 rows x 7 columns]

# %% [markdown]
# ### get_eligible
#
# Returns a DataFrame about eligible individuals for COVID-19 vaccine administration in Italy.

# %%
icl.get_eligible()
# Out:
#     region_code   region age_group  population
# 0           ABR  Abruzzo     12-19       94727
# 1           ABR  Abruzzo     20-29      125230
# 2           ABR  Abruzzo     30-39      146965
# 3           ABR  Abruzzo     40-49      187162
# 4           ABR  Abruzzo     50-59      208686
# ..          ...      ...       ...         ...
# 163         VEN   Veneto     40-49      717331
# 164         VEN   Veneto     50-59      806474
# 165         VEN   Veneto     60-69      610635
# 166         VEN   Veneto     70-79      494721
# 167         VEN   Veneto       80+      368984
#
# [168 rows x 4 columns]

# %% [markdown]
# ### get_equip_contracts
#
# Returns a DataFrame about COVID-19 pandemic equipment contracts in Italy.

# %%
icl.get_equip_contracts()
# Out:
#                                  manufacturer country  \
# 0   Dispositivi Protezione Individuale S.r.l.     ITA
# 1   Dispositivi Protezione Individuale S.r.l.     ITA
# 2                                  BLS S.r.l.     ITA
# 3                                  BLS S.r.l.     ITA
# 4                                  BLS S.r.l.     ITA
# ..                                        ...     ...
# 85                         Agmin Italy S.p.A.     ITA
# 86                         Agmin Italy S.p.A.     ITA
# 87                                IMSTec Gmbh     DEU
# 88                                IMSTec Gmbh     DEU
# 89            Tokyo Medical Consulting Co Ltd     JPN
#
#                                   product_group  \
# 0   Dispositivi di protezione individuale (DPI)
# 1   Dispositivi di protezione individuale (DPI)
# 2   Dispositivi di protezione individuale (DPI)
# 3   Dispositivi di protezione individuale (DPI)
# 4   Dispositivi di protezione individuale (DPI)
# ..                                          ...
# 85                         Dispositivi medicali
# 86  Dispositivi di protezione individuale (DPI)
# 87  Dispositivi di protezione individuale (DPI)
# 88                         Dispositivi medicali
# 89                         Dispositivi medicali
#
#                       article_subgroup  category           subcategory  \
# 0   Maschere FFP2 / FFP3 / equivalenti  Maschere         Maschere FFP2
# 1   Maschere FFP2 / FFP3 / equivalenti  Maschere         Maschere FFP3
# 2   Maschere FFP2 / FFP3 / equivalenti  Maschere         Maschere FFP2
# 3   Maschere FFP2 / FFP3 / equivalenti  Maschere         Maschere FFP3
# 4   Maschere FFP2 / FFP3 / equivalenti  Maschere         Maschere FFP2
# ..                                 ...       ...                   ...
# 85                Maschere chirurgiche  Maschere  Maschere chirurgiche
# 86                                Tute      Tute                  Tute
# 87  Maschere FFP2 / FFP3 / equivalenti  Maschere         Maschere FFP2
# 88                Maschere chirurgiche  Maschere  Maschere chirurgiche
# 89                Maschere chirurgiche  Maschere  Maschere chirurgiche
#
#    equipment_kind                equipment negotiation_protocol  \
# 0     consumabili            Facciali FFP2        COVID/0009489
# 1     consumabili            Facciali FFP3        COVID/0009489
# 2     consumabili            Facciali FFP2        COVID/0009487
# 3     consumabili            Facciali FFP3        COVID/0009487
# 4     consumabili            Facciali FFP2        COVID/0015655
# ..            ...                      ...                  ...
# 85    consumabili  Mascherine ASTM LEVEL 1        COVID/0015204
# 86    consumabili            Tute isolanti        COVID/0015204
# 87    consumabili  Maschere Facciali  FFP2        COVID/0015197
# 88    consumabili   Mascherine chirurgiche        COVID/0015197
# 89    consumabili   Mascherine chirurgiche        COVID/0016065
#
#    negotiation_date  ... errata_file   cig_type          cig quantity  \
# 0        2020-02-26  ...         NaN        cig   8232612656    13000
# 1        2020-02-26  ...         NaN        cig   8232612656    11000
# 2        2020-02-26  ...         NaN  smart-cig   Z142C53CAC     1440
# 3        2020-02-26  ...         NaN  smart-cig   Z142C53CAC      480
# 4        2020-03-22  ...         NaN        cig  82533900 E4    80640
# ..              ...  ...         ...        ...          ...      ...
# 85       2020-03-19  ...         NaN        cig   82523495D3   101600
# 86       2020-03-19  ...         NaN        cig   82523495D3     4000
# 87       2020-03-19  ...         NaN        NaN          NaN   450000
# 88       2020-03-19  ...         NaN        NaN          NaN   450000
# 89       2020-03-24  ...         NaN        NaN          NaN   260000
#
#    unit_price total_price agreement_state  ceded  notes  update_date
# 0     2.28000    29640.00         firmato     no    NaN   2020-04-22
# 1     5.20000    57200.00         firmato     no    NaN   2020-04-22
# 2     1.76000     2534.40         firmato     no    NaN   2020-04-22
# 3     5.61000     2692.80         firmato     no    NaN   2020-04-22
# 4     1.80000   145152.00         firmato     si    NaN   2020-04-22
# ..        ...         ...             ...    ...    ...          ...
# 85    0.75000    76200.00         firmato     si    NaN   2020-04-22
# 86   16.43000    65720.00         firmato     si    NaN   2020-04-22
# 87    3.10000  1395000.00         firmato     no    NaN   2020-04-22
# 88    0.89000   400500.00         firmato     no    NaN   2020-04-22
# 89    1.67351   435112.64         firmato     no    NaN   2020-04-22
#
# [90 rows x 24 columns]

# %% [markdown]
# ### get_equip_contracts_payments
#
# Returns a DataFrame about payments for COVID-19 pandemic equipment in Italy.

# %%
icl.get_equip_contracts_payments()
# Out:
#    negotiation_protocol  total_equipment   total_paid  donations  other_funds  \
# 0         COVID/0009489     8.684000e+04     86840.00        NaN          NaN
# 1         COVID/0009487     5.227200e+03      5229.20        NaN          NaN
# 2         COVID/0015655     1.451520e+05     63504.00        NaN          NaN
# 3         COVID/0009486     1.691280e+04     16912.80        NaN          NaN
# 4           ABI/0010027     1.430000e+05    120120.00        NaN          NaN
# 5         COVID/0012927     3.120000e+06   1169740.00        NaN          NaN
# 6         COVID/0010316     2.270400e+06   2270400.00        NaN          NaN
# 7          COVID/009726     1.160000e+06   1160000.00        NaN          NaN
# 8         COVID/0010620     2.434600e+05    243460.00        NaN          NaN
# 9           ABI/0011769     1.000000e+05    100000.00        NaN          NaN
# 10        COVID/0012924     3.432721e+06   3432721.45        NaN          NaN
# 11        COVID/0013562     1.288000e+07  12679675.59        NaN          NaN
# 12                14399     1.160000e+05    116000.00        NaN          NaN
# 13        COVID/0014561     7.440000e+06   1860000.00        NaN          NaN
# 14        COVID/0015043     8.000000e+04     80000.00        NaN          NaN
# 15        COVID/0015684     5.910000e+06         0.00        NaN          NaN
# 16        COVID/0015685     9.600000e+06         0.00        NaN          NaN
# 17        COVID/0010026     1.817584e+05    181758.40        NaN          NaN
# 18        COVID/0010621     4.425840e+04     44258.40        NaN          NaN
# 19        COVID/0010981     2.645000e+06    768477.25        NaN          NaN
# 20        COVID/0012127     7.921250e+05    727375.00        NaN          NaN
# 21        COVID/0010418     7.000000e+04     70000.00        NaN          NaN
# 22                10956     2.048000e+06   1985587.20        NaN          NaN
# 23        COVID/0012120     3.328000e+06   2030000.00        NaN          NaN
# 24        COVID/0010980     6.648604e+04     66486.04        NaN          NaN
# 25        COVID/0014743     2.300000e+07  13800000.00        NaN          NaN
# 26        COVID/0014751     2.200000e+06   1320000.00        NaN          NaN
# 27      COR 630/0011290     3.110400e+05    311030.00        NaN          NaN
# 28          ABI/0011770     6.220800e+05    489888.00        NaN          NaN
# 29        COVID/0011718     3.327680e+06   3327680.00        NaN          NaN
# 30        COVID/0011719     2.030960e+07   4984720.00        NaN          NaN
# 31          ABI/0011772     2.160000e+06   1987200.00        NaN          NaN
# 32        COVID/0012843     8.250000e+06         0.00        NaN          NaN
# 33        COVID/0013311     2.380000e+06   1222725.00        NaN          NaN
# 34        COVID/0013541     2.817500e+03      2817.15        NaN          NaN
# 35        COVID/0013525     2.600000e+04     26000.00        NaN          NaN
# 36        COVID/0013734     2.660000e+06   1900000.00        NaN          NaN
# 37                13942     1.250000e+07  12500000.00        NaN          NaN
# 38        COVID/0013846     1.475000e+06   1503224.00        NaN          NaN
# 39        COVID/0014758     2.822400e+04     28224.00        NaN          NaN
# 40        COVID/0013739     1.337720e+07  13377200.00        NaN          NaN
# 41        COVID/0015683     1.211940e+08  16141740.00        NaN          NaN
# 42                14044     1.360000e+07  13600000.00        NaN          NaN
# 43        COVID/0015636     3.400000e+07  11526000.00        NaN          NaN
# 44        COVID/0013880     8.000000e+05         0.00        NaN          NaN
# 45        COVID/0014549     1.065000e+07   5067714.00        NaN          NaN
# 46        COVID/0015047     3.400000e+06         0.00        NaN          NaN
# 47        COVID/0015042     2.200000e+07    778800.00        NaN          NaN
# 48        COVID/0015207     1.260000e+04     12600.00        NaN          NaN
# 49        COVID/0015204     1.939200e+05         0.00        NaN          NaN
# 50                15197     1.795500e+06   1731159.50        NaN          NaN
# 51        COVID/0016065     4.351126e+05    435112.64        NaN          NaN
#
#     payment_fund ceded  notes update_date
# 0            NaN    no    NaN  2020-07-02
# 1            NaN    no    NaN  2021-02-05
# 2            NaN    si    NaN  2020-12-05
# 3            NaN    no    NaN  2020-02-07
# 4            NaN    no    NaN  2020-02-07
# 5            NaN    si    NaN  2020-12-05
# 6            NaN    no    NaN  2020-12-05
# 7            NaN    no    NaN  2020-02-07
# 8            NaN    no    NaN  2020-12-05
# 9            NaN    no    NaN  2020-12-05
# 10           NaN    no    NaN  2020-12-05
# 11           NaN    no    NaN  2020-12-22
# 12           NaN    no    NaN  2020-05-12
# 13           NaN    si    NaN  2020-05-12
# 14           NaN    no    NaN  2020-12-05
# 15           NaN    si    NaN  2020-12-05
# 16           NaN    si    NaN  2020-12-05
# 17           NaN    no    NaN  2020-12-22
# 18           NaN    no    NaN  2020-12-22
# 19           NaN    si    NaN  2020-05-12
# 20           NaN    si    NaN  2020-05-12
# 21           NaN    no    NaN  2020-12-22
# 22           NaN    no    NaN  2020-05-12
# 23           NaN    si    NaN  2020-05-12
# 24           NaN    no    NaN  2020-12-22
# 25           NaN    no    NaN  2020-05-12
# 26           NaN    no    NaN  2020-05-12
# 27           NaN    no    NaN  2020-05-12
# 28           NaN    si    NaN  2020-07-02
# 29           NaN    no    NaN  2020-05-12
# 30           NaN    si    NaN  2020-07-02
# 31           NaN    no    NaN  2020-05-12
# 32           NaN    no    NaN  2020-05-12
# 33           NaN    si    NaN  2020-05-12
# 34           NaN    no    NaN  2021-02-05
# 35           NaN    no    NaN  2021-02-05
# 36           NaN    no    NaN  2020-05-12
# 37           NaN    no    NaN  2020-05-12
# 38           NaN    si    NaN  2020-12-22
# 39           NaN    no    NaN  2020-07-02
# 40           NaN    si    NaN  2020-05-12
# 41           NaN    si    NaN  2020-05-12
# 42           NaN    si    NaN  2020-05-12
# 43           NaN    si    NaN  2020-05-12
# 44           NaN    no    NaN  2020-05-12
# 45           NaN    si    NaN  2020-05-12
# 46           NaN    si    NaN  2020-05-12
# 47           NaN    si    NaN  2020-05-12
# 48           NaN    no    NaN  2020-07-02
# 49           NaN    si    NaN  2020-05-12
# 50           NaN    no    NaN  2020-05-12
# 51           NaN    no    NaN  2020-05-12

# %% [markdown]
# ### get_istat_region_data
#
# Returns a DataFrame with data about Italian regions, as taken from ISTAT (Italian National Institute of Statistics).

# %%
icl.get_istat_region_data()
# Out:
#      region_code NUTS1_code NUTS1_description NUTS2_code   region  \
# 0             13        ITF               Sud       ITF1  Abruzzo
# 1             13        ITF               Sud       ITF1  Abruzzo
# 2             13        ITF               Sud       ITF1  Abruzzo
# 3             13        ITF               Sud       ITF1  Abruzzo
# 4             13        ITF               Sud       ITF1  Abruzzo
# ..           ...        ...               ...        ...      ...
# 205            5        ITH          Nord-Est       ITH3   Veneto
# 206            5        ITH          Nord-Est       ITH3   Veneto
# 207            5        ITH          Nord-Est       ITH3   Veneto
# 208            5        ITH          Nord-Est       ITH3   Veneto
# 209            5        ITH          Nord-Est       ITH3   Veneto
#
#     region_abbreviation        lat       long age_range   males  females  \
# 0                   ABR  42.351222  13.398438      0-15   87423    82474
# 1                   ABR  42.351222  13.398438     16-19   24402    22349
# 2                   ABR  42.351222  13.398438     20-29   67472    62611
# 3                   ABR  42.351222  13.398438     30-39   76472    74241
# 4                   ABR  42.351222  13.398438     40-49   94745    95315
# ..                  ...        ...        ...       ...     ...      ...
# 205                 VEN  45.434905  12.338452     50-59  399024   400436
# 206                 VEN  45.434905  12.338452     60-69  293238   309972
# 207                 VEN  45.434905  12.338452     70-79  228669   265774
# 208                 VEN  45.434905  12.338452     80-89  115439   177591
# 209                 VEN  45.434905  12.338452       90+   16430    49080
#
#       total
# 0    169897
# 1     46751
# 2    130083
# 3    150713
# 4    190060
# ..      ...
# 205  799460
# 206  603210
# 207  494443
# 208  293030
# 209   65510
#
# [210 rows x 12 columns]

# %% [markdown]
# ### get_national_trend
#
# Returns a DataFrame about the COVID-19 pandemic situation in Italy at a national scale.

# %%
icl.get_national_trend()
# Out:
#                    date country  hospitalized_with_symptoms  intensive_care  \
# 0   2020-02-24 18:00:00     ITA                         101              26
# 1   2020-02-25 18:00:00     ITA                         114              35
# 2   2020-02-26 18:00:00     ITA                         128              36
# 3   2020-02-27 18:00:00     ITA                         248              56
# 4   2020-02-28 18:00:00     ITA                         345              64
# ..                  ...     ...                         ...             ...
# 591 2021-10-07 17:00:00     ITA                        2824             403
# 592 2021-10-08 17:00:00     ITA                        2742             383
# 593 2021-10-09 17:00:00     ITA                        2692             367
# 594 2021-10-10 17:00:00     ITA                        2651             364
# 595 2021-10-11 17:00:00     ITA                        2688             374
#
#      hospitalized  isolation  cases  cases_variation  new_cases  \
# 0             127         94    221                0        221
# 1             150        162    311               90         93
# 2             164        221    385               74         78
# 3             304        284    588              203        250
# 4             409        412    821              233        238
# ..            ...        ...    ...              ...        ...
# 591          3227      83946  87173            -1074       2938
# 592          3125      82801  85926            -1247       3023
# 593          3059      82243  85302             -624       2748
# 594          3015      81793  84808             -494       2278
# 595          3062      81044  84106             -702       1516
#
#      recovered_released  ...     swabs      tested  notes  intensive_care_in  \
# 0                     1  ...      4324         NaN    NaN                NaN
# 1                     1  ...      8623         NaN    NaN                NaN
# 2                     3  ...      9587         NaN    NaN                NaN
# 3                    45  ...     12014         NaN    NaN                NaN
# 4                    46  ...     15695         NaN    NaN                NaN
# ..                  ...  ...       ...         ...    ...                ...
# 591             4473903  ...  94444592  34626978.0    NaN               24.0
# 592             4478137  ...  94716158  34679503.0    NaN               17.0
# 593             4481462  ...  95061127  34739517.0    NaN               16.0
# 594             4484207  ...  95331171  34789334.0    NaN               13.0
# 595             4486391  ...  95445947  34815383.0    NaN               18.0
#
#      test_notes  case_notes molecular_test_cases  antigen_test_cases  \
# 0           NaN         NaN                  NaN                 NaN
# 1           NaN         NaN                  NaN                 NaN
# 2           NaN         NaN                  NaN                 NaN
# 3           NaN         NaN                  NaN                 NaN
# 4           NaN         NaN                  NaN                 NaN
# ..          ...         ...                  ...                 ...
# 591         NaN         NaN            4519532.0            172742.0
# 592         NaN         NaN            4522420.0            172871.0
# 593         NaN         NaN            4524928.0            173110.0
# 594         NaN         NaN            4527045.0            173271.0
# 595         NaN         NaN            4528481.0            173351.0
#
#      molecular_tests  antigen_tests
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ..               ...            ...
# 591       60863483.0     33581109.0
# 592       60971361.0     33744797.0
# 593       61075375.0     33985752.0
# 594       61154936.0     34176235.0
# 595       61203810.0     34242137.0
#
# [596 rows x 24 columns]

# %% [markdown]
# ### get_national_trend_latest
#
# Same as get_national_trend, but only returns data referred to the current day.

# %%
icl.get_national_trend_latest()
# Out:
#                  date country  hospitalized_with_symptoms  intensive_care  \
# 0 2021-10-11 17:00:00     ITA                        2688             374
#
#    hospitalized  isolation  cases  cases_variation  new_cases  \
# 0          3062      81044  84106             -702       1516
#
#    recovered_released  ...     swabs    tested  notes  intensive_care_in  \
# 0             4486391  ...  95445947  34815383    NaN                 18
#
#    test_notes  case_notes  molecular_test_cases  antigen_test_cases  \
# 0         NaN         NaN               4528481              173351
#
#    molecular_tests  antigen_tests
# 0         61203810       34242137
#
# [1 rows x 24 columns]

# %% [markdown]
# ### get_over_80
#
# Returns a DataFrame with data about individuals aged over 80 in Italy.

# %%
icl.get_over_80()
# Out:
#     region_code NUTS1_code NUTS1_description NUTS2_code  \
# 0            13        ITF               Sud       ITF1
# 1            17        ITF               Sud       ITF5
# 2            21        ITH          Nord-Est       ITH1
# 3            18        ITF               Sud       ITF6
# 4            15        ITF               Sud       ITF3
# 5             8        ITH          Nord-Est       ITH5
# 6             6        ITH          Nord-Est       ITH4
# 7            12        ITI            Centro       ITI4
# 8             7        ITC        Nord-Ovest       ITC3
# 9             3        ITC        Nord-Ovest       ITC4
# 10           11        ITI            Centro       ITI3
# 11           14        ITF               Sud       ITF2
# 12            1        ITC        Nord-Ovest       ITC1
# 13           16        ITF               Sud       ITF4
# 14           20        ITG             Isole       ITG2
# 15           19        ITG             Isole       ITG1
# 16            9        ITI            Centro       ITI1
# 17           22        ITH          Nord-Est       ITH2
# 18           10        ITI            Centro       ITI2
# 19            2        ITC        Nord-Ovest       ITC2
# 20            5        ITH          Nord-Est       ITH3
#
#                    region age_range   males  females   total
# 0                 Abruzzo    Over80   39826    64177  104003
# 1              Basilicata    Over80   16995    26935   43930
# 2                 Bolzano    Over80   12769    20504   33273
# 3                Calabria    Over80   51068    79710  130778
# 4                Campania    Over80  112763   191554  304317
# 5          Emilia-Romagna    Over80  140567   228786  369353
# 6   Friuli Venezia Giulia    Over80   37412    66081  103493
# 7                   Lazio    Over80  150267   250338  400605
# 8                 Liguria    Over80   56742    99227  155969
# 9               Lombardia    Over80  269371   468269  737640
# 10                 Marche    Over80   50657    82708  133365
# 11                 Molise    Over80    9744    16513   26257
# 12               Piemonte    Over80  139010   232390  371400
# 13                 Puglia    Over80  103121   165005  268126
# 14               Sardegna    Over80   43983    72300  116283
# 15                Sicilia    Over80  121024   194891  315915
# 16                Toscana    Over80  121378   199211  320589
# 17                 Trento    Over80   13926    24460   38386
# 18                 Umbria    Over80   29256    48661   77917
# 19          Valle d'Aosta    Over80    3451     6113    9564
# 20                 Veneto    Over80  131869   226671  358540

# %% [markdown]
# ### get_province_cases
#
# Returns a DataFrame about COVID-19 cases per province in Italy.

# %%
icl.get_province_cases()
# Out:
#                      date country  region_code   region  province_code  \
# 0     2020-02-24 18:00:00     ITA           13  Abruzzo             66
# 1     2020-02-24 18:00:00     ITA           13  Abruzzo             67
# 2     2020-02-24 18:00:00     ITA           13  Abruzzo             68
# 3     2020-02-24 18:00:00     ITA           13  Abruzzo             69
# 4     2020-02-24 18:00:00     ITA           13  Abruzzo            979
# ...                   ...     ...          ...      ...            ...
# 86237 2021-10-11 17:00:00     ITA            5   Veneto             27
# 86238 2021-10-11 17:00:00     ITA            5   Veneto             28
# 86239 2021-10-11 17:00:00     ITA            5   Veneto             29
# 86240 2021-10-11 17:00:00     ITA            5   Veneto            899
# 86241 2021-10-11 17:00:00     ITA            5   Veneto            999
#
#                                    province province_abbreviation        lat  \
# 0                                  L'Aquila                    AQ  42.351222
# 1                                    Teramo                    TE  42.658918
# 2                                   Pescara                    PE  42.464584
# 3                                    Chieti                    CH  42.351032
# 4      In fase di definizione/aggiornamento                   NaN        NaN
# ...                                     ...                   ...        ...
# 86237                               Venezia                    VE  45.434905
# 86238                                Padova                    PD  45.406930
# 86239                                Rovigo                    RO  45.071073
# 86240    Fuori Regione / Provincia Autonoma                   NaN        NaN
# 86241  In fase di definizione/aggiornamento                   NaN        NaN
#
#             long  cumulative_cases notes NUTS1_code NUTS2_code NUTS3_code
# 0      13.398438                 0   NaN        NaN        NaN        NaN
# 1      13.704400                 0   NaN        NaN        NaN        NaN
# 2      14.213648                 0   NaN        NaN        NaN        NaN
# 3      14.167546                 0   NaN        NaN        NaN        NaN
# 4            NaN                 0   NaN        NaN        NaN        NaN
# ...          ...               ...   ...        ...        ...        ...
# 86237  12.338452             77540   NaN        ITH       ITH3      ITH35
# 86238  11.876087             90747   NaN        ITH       ITH3      ITH36
# 86239  11.790070             15803   NaN        ITH       ITH3      ITH37
# 86240        NaN              6053   NaN        ITH       ITH3        NaN
# 86241        NaN              1583   NaN        ITH       ITH3        NaN
#
# [86242 rows x 14 columns]

# %% [markdown]
# ### get_province_cases_latest
#
# Same as get_province_cases, but only returns data referred to the current day.

# %%
icl.get_province_cases_latest()
# Out:
#                    date country  region_code   region  province_code  \
# 0   2021-10-11 17:00:00     ITA           13  Abruzzo             66
# 1   2021-10-11 17:00:00     ITA           13  Abruzzo             67
# 2   2021-10-11 17:00:00     ITA           13  Abruzzo             68
# 3   2021-10-11 17:00:00     ITA           13  Abruzzo             69
# 4   2021-10-11 17:00:00     ITA           13  Abruzzo            879
# ..                  ...     ...          ...      ...            ...
# 144 2021-10-11 17:00:00     ITA            5   Veneto             27
# 145 2021-10-11 17:00:00     ITA            5   Veneto             28
# 146 2021-10-11 17:00:00     ITA            5   Veneto             29
# 147 2021-10-11 17:00:00     ITA            5   Veneto            899
# 148 2021-10-11 17:00:00     ITA            5   Veneto            999
#
#                                  province province_abbreviation        lat  \
# 0                                L'Aquila                    AQ  42.351222
# 1                                  Teramo                    TE  42.658918
# 2                                 Pescara                    PE  42.464584
# 3                                  Chieti                    CH  42.351032
# 4      Fuori Regione / Provincia Autonoma                   NaN        NaN
# ..                                    ...                   ...        ...
# 144                               Venezia                    VE  45.434905
# 145                                Padova                    PD  45.406930
# 146                                Rovigo                    RO  45.071073
# 147    Fuori Regione / Provincia Autonoma                   NaN        NaN
# 148  In fase di definizione/aggiornamento                   NaN        NaN
#
#           long  cumulative_cases  notes NUTS1_code NUTS2_code NUTS3_code
# 0    13.398438             20773    NaN        ITF       ITF1      ITF11
# 1    13.704400             19614    NaN        ITF       ITF1      ITF12
# 2    14.213648             19675    NaN        ITF       ITF1      ITF13
# 3    14.167546             20785    NaN        ITF       ITF1      ITF14
# 4          NaN               669    NaN        ITF       ITF1        NaN
# ..         ...               ...    ...        ...        ...        ...
# 144  12.338452             77540    NaN        ITH       ITH3      ITH35
# 145  11.876087             90747    NaN        ITH       ITH3      ITH36
# 146  11.790070             15803    NaN        ITH       ITH3      ITH37
# 147        NaN              6053    NaN        ITH       ITH3        NaN
# 148        NaN              1583    NaN        ITH       ITH3        NaN
#
# [149 rows x 14 columns]

# %% [markdown]
# ### get_region_cases
#
# Returns a DataFrame about COVID-19 cases per region in Italy.

# %%
icl.get_region_cases()
# Out:
#                      date country  region_code          region        lat  \
# 0     2020-02-24 18:00:00     ITA           13         Abruzzo  42.351222
# 1     2020-02-24 18:00:00     ITA           17      Basilicata  40.639471
# 2     2020-02-24 18:00:00     ITA           18        Calabria  38.905976
# 3     2020-02-24 18:00:00     ITA           15        Campania  40.839566
# 4     2020-02-24 18:00:00     ITA            8  Emilia-Romagna  44.494367
# ...                   ...     ...          ...             ...        ...
# 12511 2021-10-11 17:00:00     ITA           19         Sicilia  38.115697
# 12512 2021-10-11 17:00:00     ITA            9         Toscana  43.769231
# 12513 2021-10-11 17:00:00     ITA           10          Umbria  43.106758
# 12514 2021-10-11 17:00:00     ITA            2   Valle d'Aosta  45.737503
# 12515 2021-10-11 17:00:00     ITA            5          Veneto  45.434905
#
#             long  hospitalized_with_symptoms  intensive_care  hospitalized  \
# 0      13.398438                           0               0             0
# 1      15.805148                           0               0             0
# 2      16.594402                           0               0             0
# 3      14.250850                           0               0             0
# 4      11.341721                          10               2            12
# ...          ...                         ...             ...           ...
# 12511  13.362357                         345              42           387
# 12512  11.255889                         220              25           245
# 12513  12.388247                          40               5            45
# 12514   7.320149                           2               0             2
# 12515  12.338452                         146              30           176
#
#        isolation  ...                                              notes  \
# 0              0  ...                                                NaN
# 1              0  ...                                                NaN
# 2              0  ...                                                NaN
# 3              0  ...                                                NaN
# 4              6  ...                                                NaN
# ...          ...  ...                                                ...
# 12511      10266  ...  DECEDUTI: N. 2 IL 10/10/21 - N. 2 IL 09/10/21 ...
# 12512       5495  ...                                                NaN
# 12513        604  ...                                                NaN
# 12514        108  ...                                                NaN
# 12515       9263  ...   Il dato dei casi confermati da test antigenic...
#
#        intensive_care_in  test_notes  case_notes  molecular_test_cases  \
# 0                    NaN         NaN         NaN                   NaN
# 1                    NaN         NaN         NaN                   NaN
# 2                    NaN         NaN         NaN                   NaN
# 3                    NaN         NaN         NaN                   NaN
# 4                    NaN         NaN         NaN                   NaN
# ...                  ...         ...         ...                   ...
# 12511                1.0         NaN         NaN              301889.0
# 12512                1.0         NaN         NaN              279886.0
# 12513                0.0         NaN         NaN               64128.0
# 12514                0.0         NaN         NaN               11373.0
# 12515                0.0         NaN         NaN              458009.0
#
#        antigen_test_cases  molecular_tests  antigen_tests  NUTS1_code  \
# 0                     NaN              NaN            NaN         NaN
# 1                     NaN              NaN            NaN         NaN
# 2                     NaN              NaN            NaN         NaN
# 3                     NaN              NaN            NaN         NaN
# 4                     NaN              NaN            NaN         NaN
# ...                   ...              ...            ...         ...
# 12511                 0.0        3264681.0      3183660.0         ITG
# 12512              4734.0        4626032.0      1955205.0         ITI
# 12513                 0.0        1149336.0       853118.0         ITI
# 12514               834.0         110247.0        86671.0         ITC
# 12515             14663.0        6842039.0      5496275.0         ITH
#
#        NUTS2_code
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 12511        ITG1
# 12512        ITI1
# 12513        ITI2
# 12514        ITC2
# 12515        ITH3
#
# [12516 rows x 30 columns]

# %% [markdown]
# ### get_region_cases_latest
#
# Same as get_region_cases, but only returns data referred to the current day.

# %%
icl.get_region_cases_latest()
# Out:
#                   date country  region_code                 region        lat  \
# 0  2021-10-11 17:00:00     ITA           13                Abruzzo  42.351222
# 1  2021-10-11 17:00:00     ITA           17             Basilicata  40.639471
# 2  2021-10-11 17:00:00     ITA           18               Calabria  38.905976
# 3  2021-10-11 17:00:00     ITA           15               Campania  40.839566
# 4  2021-10-11 17:00:00     ITA            8         Emilia-Romagna  44.494367
# 5  2021-10-11 17:00:00     ITA            6  Friuli Venezia Giulia  45.649435
# 6  2021-10-11 17:00:00     ITA           12                  Lazio  41.892770
# 7  2021-10-11 17:00:00     ITA            7                Liguria  44.411493
# 8  2021-10-11 17:00:00     ITA            3              Lombardia  45.466794
# 9  2021-10-11 17:00:00     ITA           11                 Marche  43.616760
# 10 2021-10-11 17:00:00     ITA           14                 Molise  41.557748
# 11 2021-10-11 17:00:00     ITA           21           P.A. Bolzano  46.499335
# 12 2021-10-11 17:00:00     ITA           22            P.A. Trento  46.068935
# 13 2021-10-11 17:00:00     ITA            1               Piemonte  45.073274
# 14 2021-10-11 17:00:00     ITA           16                 Puglia  41.125596
# 15 2021-10-11 17:00:00     ITA           20               Sardegna  39.215312
# 16 2021-10-11 17:00:00     ITA           19                Sicilia  38.115697
# 17 2021-10-11 17:00:00     ITA            9                Toscana  43.769231
# 18 2021-10-11 17:00:00     ITA           10                 Umbria  43.106758
# 19 2021-10-11 17:00:00     ITA            2          Valle d'Aosta  45.737503
# 20 2021-10-11 17:00:00     ITA            5                 Veneto  45.434905
#
#          long  hospitalized_with_symptoms  intensive_care  hospitalized  \
# 0   13.398438                          49               6            55
# 1   15.805148                          24               0            24
# 2   16.594402                         107              10           117
# 3   14.250850                         178              14           192
# 4   11.341721                         322              46           368
# 5   13.768136                          44               9            53
# 6   12.483667                         361              51           412
# 7    8.932699                          49               6            55
# 8    9.190347                         325              55           380
# 9   13.518875                          44              12            56
# 10  14.659161                           2               1             3
# 11  11.356624                          25               6            31
# 12  11.121231                          15               3            18
# 13   7.680687                         179              19           198
# 14  16.867367                         134              21           155
# 15   9.110616                          77              13            90
# 16  13.362357                         345              42           387
# 17  11.255889                         220              25           245
# 18  12.388247                          40               5            45
# 19   7.320149                           2               0             2
# 20  12.338452                         146              30           176
#
#     isolation  ...                                              notes  \
# 0        1360  ...                                                NaN
# 1        1117  ...  Il numero totale dei decessi ne comprende n. 2...
# 2        2752  ...                                                NaN
# 3        6024  ...                                                NaN
# 4       14675  ...                                                NaN
# 5         795  ...                                                NaN
# 6        8722  ...                                                NaN
# 7         879  ...  In Regione Liguria la positività al test antig...
# 8        8663  ...                                                NaN
# 9        2235  ...                                                NaN
# 10         78  ...                                                NaN
# 11        749  ...                                                NaN
# 12        324  ...                                                NaN
# 13       3051  ...                                                NaN
# 14       2247  ...                                                NaN
# 15       1637  ...  Si segnala che nella rilevazione di ieri, nell...
# 16      10266  ...  DECEDUTI: N. 2 IL 10/10/21 - N. 2 IL 09/10/21 ...
# 17       5495  ...                                                NaN
# 18        604  ...                                                NaN
# 19        108  ...                                                NaN
# 20       9263  ...   Il dato dei casi confermati da test antigenic...
#
#     intensive_care_in  test_notes  \
# 0                   0         NaN
# 1                   0         NaN
# 2                   1         NaN
# 3                   2         NaN
# 4                   3         NaN
# 5                   0         NaN
# 6                   3         NaN
# 7                   0         NaN
# 8                   2         NaN
# 9                   0         NaN
# 10                  0         NaN
# 11                  0         NaN
# 12                  0         NaN
# 13                  2         NaN
# 14                  2         NaN
# 15                  1         NaN
# 16                  1         NaN
# 17                  1         NaN
# 18                  0         NaN
# 19                  0         NaN
# 20                  0         NaN
#
#                                            case_notes  molecular_test_cases  \
# 0                                                 NaN                 81630
# 1                                                 NaN                 30444
# 2                                                 NaN                 84916
# 3                                                 NaN                447623
# 4                                                 NaN                426257
# 5                                                 NaN                 99052
# 6                                                 NaN                378170
# 7   *di cui 39 reinfezioni a partire dal 3/09/2021...                113371
# 8                                                 NaN                821446
# 9                                                 NaN                114549
# 10                                                NaN                 14546
# 11  2 nuovi positivi di cui un test antigenico con...                 64247
# 12                                                NaN                 33744
# 13                                                NaN                359032
# 14                                                NaN                268609
# 15                                                NaN                 75560
# 16                                                NaN                301889
# 17                                                NaN                279886
# 18                                                NaN                 64128
# 19                                                NaN                 11373
# 20                                                NaN                458009
#
#     antigen_test_cases  molecular_tests  antigen_tests  NUTS1_code  NUTS2_code
# 0                    0          1435374         874865         ITF        ITF1
# 1                    0           449041          22872         ITF        ITF5
# 2                   16          1059703         164276         ITF        ITF6
# 3                11588          5318934        1452449         ITF        ITF3
# 4                  363          5942404        3183558         ITH        ITH5
# 5                15353          2158172         673018         ITH        ITH4
# 6                 9229          5622649        3728527         ITI        ITI4
# 7                    0          1661635         728198         ITC        ITC3
# 8                65448         10922946        4645411         ITC        ITC4
# 9                    0          1362137         213069         ITI        ITI3
# 10                   0           265065          13030         ITF        ITF2
# 11               13232           660281        1473722         ITH        ITH1
# 12               14908           723617         410868         ITH        ITH2
# 13               21654          3543314        3408151         ITC        ITC1
# 14                1225          2819137         993265         ITF        ITF4
# 15                 104          1267066         681929         ITG        ITG2
# 16                   0          3264681        3183660         ITG        ITG1
# 17                4734          4626032        1955205         ITI        ITI1
# 18                   0          1149336         853118         ITI        ITI2
# 19                 834           110247          86671         ITC        ITC2
# 20               14663          6842039        5496275         ITH        ITH3
#
# [21 rows x 30 columns]

# %% [markdown]
# ### get_vaccine_admin
#
# Returns a DataFrame about COVID-19 vaccine administration in Italy.

# %%
icl.get_vaccine_admin()
# Out:
#              date             manufacturer region_code age_group  males  \
# 0      2020-12-27          Pfizer/BioNTech         ABR     20-29      1
# 1      2020-12-27          Pfizer/BioNTech         ABR     30-39      1
# 2      2020-12-27          Pfizer/BioNTech         ABR     40-49      1
# 3      2020-12-27          Pfizer/BioNTech         ABR     50-59      7
# 4      2020-12-27          Pfizer/BioNTech         ABR     60-69     12
# ...           ...                      ...         ...       ...    ...
# 136103 2021-10-11  Vaxzevria (AstraZeneca)         SAR     70-79      8
# 136104 2021-10-11  Vaxzevria (AstraZeneca)         SAR     80-89      0
# 136105 2021-10-11  Vaxzevria (AstraZeneca)         SIC     30-39      1
# 136106 2021-10-11  Vaxzevria (AstraZeneca)         SIC     70-79      1
# 136107 2021-10-11  Vaxzevria (AstraZeneca)         VEN     60-69      0
#
#         females  first_dose  second_dose  previously_infected  extra_dose  \
# 0             1           2            0                    0           0
# 1             4           5            0                    0           0
# 2             8           9            0                    0           0
# 3             6          13            0                    0           0
# 4             4          16            0                    0           0
# ...         ...         ...          ...                  ...         ...
# 136103       15           1           22                    0           0
# 136104        2           0            2                    0           0
# 136105        0           0            1                    0           0
# 136106        1           0            2                    0           0
# 136107        1           0            1                    0           0
#
#        NUTS1_code NUTS2_code  ISTAT_region_code    region
# 0             ITF       ITF1                 13   Abruzzo
# 1             ITF       ITF1                 13   Abruzzo
# 2             ITF       ITF1                 13   Abruzzo
# 3             ITF       ITF1                 13   Abruzzo
# 4             ITF       ITF1                 13   Abruzzo
# ...           ...        ...                ...       ...
# 136103        ITG       ITG2                 20  Sardegna
# 136104        ITG       ITG2                 20  Sardegna
# 136105        ITG       ITG1                 19   Sicilia
# 136106        ITG       ITG1                 19   Sicilia
# 136107        ITH       ITH3                  5    Veneto
#
# [136108 rows x 14 columns]

# %% [markdown]
# ### get_vaccine_admin_summary
#
# Returns a summary version of the DataFrame about COVID-19 vaccine administration in Italy (the latter can be called with get_vaccine_admin)

# %%
icl.get_vaccine_admin_summary()
# Out:
#            date region_code  total  males  females  first_dose  second_dose  \
# 0    2021-03-08         VDA    488    233      255         240          245
# 1    2021-04-23         UMB   6660   2821     3839        3302         3159
# 2    2021-08-12         VDA    378    204      174         118          248
# 3    2021-08-27         TOS  16312   8724     7588        7755         8020
# 4    2021-05-12         EMR  38978  18313    20665       28458         9708
# ...         ...         ...    ...    ...      ...         ...          ...
# 5982 2021-02-05         PUG   5660   2280     3380        1311         4342
# 5983 2021-03-12         SAR   6037   2637     3400        4548         1319
# 5984 2021-09-18         TOS  22236  12178    10058        5631        15912
# 5985 2021-02-14         PIE   1483    501      982         871          605
# 5986 2021-05-16         PUG  24670  11128    13542       12462        11969
#
#       previously_infected  extra_dose NUTS1_code NUTS2_code  \
# 0                       3           0        ITC       ITC2
# 1                     199           0        ITI       ITI2
# 2                      12           0        ITC       ITC2
# 3                     537           0        ITI       ITI1
# 4                     812           0        ITH       ITH5
# ...                   ...         ...        ...        ...
# 5982                    7           0        ITF       ITF4
# 5983                  170           0        ITG       ITG2
# 5984                  691           2        ITI       ITI1
# 5985                    7           0        ITC       ITC1
# 5986                  239           0        ITF       ITF4
#
#       ISTAT_region_code                          region
# 0                     2  Valle d'Aosta / Vallée d'Aoste
# 1                    10                          Umbria
# 2                     2  Valle d'Aosta / Vallée d'Aoste
# 3                     9                         Toscana
# 4                     8                  Emilia-Romagna
# ...                 ...                             ...
# 5982                 16                          Puglia
# 5983                 20                        Sardegna
# 5984                  9                         Toscana
# 5985                  1                        Piemonte
# 5986                 16                          Puglia
#
# [5987 rows x 13 columns]

# %% [markdown]
# ### get_vaccine_ages
#
# Returns a DataFrame about COVID-19 vaccine administrations in Italy, divided per age group.

# %%
icl.get_vaccine_ages()
# Out:
#   age_group     total    males  females  first_dose  second_dose  \
# 0     12-19   6028706  3080213  2948493     3143195      2788285
# 1     20-29   9511888  4950009  4561879     4945059      4374479
# 2     30-39  10102736  5173076  4929660     5263373      4636768
# 3     40-49  13324042  6588011  6736031     6854528      6181867
# 4     50-59  15434239  7554461  7879778     7914240      7152586
# 5     60-69  12643540  6122783  6520757     6489769      5873543
# 6     70-79  10708049  5022568  5685481     5374565      5124555
# 7     80-89   7047050  2928188  4118862     3440261      3370144
# 8       90+   1607534   478981  1128553      793778       763381
#
#    previously_infected  extra_dose last_update
# 0                96717         509  2021-10-11
# 1               187826        4524  2021-10-11
# 2               194155        8440  2021-10-11
# 3               270412       17235  2021-10-11
# 4               334574       32839  2021-10-11
# 5               235990       44238  2021-10-11
# 6               165054       43875  2021-10-11
# 7                80939      155706  2021-10-11
# 8                20303       30072  2021-10-11

# %% [markdown]
# ### get_vaccine_deliveries
#
# Returns a DataFrame about COVID-19 vaccine deliveries in Italy.

# %%
icl.get_vaccine_deliveries()
# Out:
#      region_code     manufacturer  number_of_doses date_of_delivery  \
# 0            ABR  Pfizer/BioNTech              135       2020-12-27
# 1            ABR  Pfizer/BioNTech             7800       2020-12-30
# 2            ABR  Pfizer/BioNTech             3900       2021-01-05
# 3            ABR  Pfizer/BioNTech             3900       2021-01-07
# 4            ABR  Pfizer/BioNTech             3900       2021-01-11
# ...          ...              ...              ...              ...
# 4930         VEN          Janssen           -15700       2021-09-28
# 4931         VEN          Moderna           110400       2021-09-29
# 4932         VEN  Pfizer/BioNTech           270270       2021-09-29
# 4933         VEN  Pfizer/BioNTech            91260       2021-10-06
# 4934         VEN          Moderna            -1200       2021-10-11
#
#      NUTS1_code NUTS2_code  ISTAT_region_code   region
# 0           ITF       ITF1                 13  Abruzzo
# 1           ITF       ITF1                 13  Abruzzo
# 2           ITF       ITF1                 13  Abruzzo
# 3           ITF       ITF1                 13  Abruzzo
# 4           ITF       ITF1                 13  Abruzzo
# ...         ...        ...                ...      ...
# 4930        ITH       ITH3                  5   Veneto
# 4931        ITH       ITH3                  5   Veneto
# 4932        ITH       ITH3                  5   Veneto
# 4933        ITH       ITH3                  5   Veneto
# 4934        ITH       ITH3                  5   Veneto
#
# [4935 rows x 8 columns]

# %% [markdown]
# ### get_vaccine_summary
#
# Returns a DataFrame with a summary of COVID-19 vaccines deliveries and administrations in Italy.

# %%
icl.get_vaccine_summary()
# Out:
#    region_code  administered_doses  delivered_doses  administration_percent  \
# 0          ABR             1889160          2267250                    83.3
# 1          BAS              811737           936665                    86.7
# 2          CAL             2515073          2861334                    87.9
# 3          CAM             7919872          9180882                    86.3
# 4          EMR             6602457          7329079                    90.1
# 5          FVG             1685555          2028975                    83.1
# 6          LAZ             8454347         10294858                    82.1
# 7          LIG             2200519          2546857                    86.4
# 8          LOM            15207277         17273600                    88.0
# 9          MAR             2148704          2507456                    85.7
# 10         MOL              457856           506050                    90.5
# 11         PAB              677291           782179                    86.6
# 12         PAT              778644           878910                    88.6
# 13         PIE             6203482          7131612                    87.0
# 14         PUG             5906848          6874647                    85.9
# 15         SAR             2410334          2751712                    87.6
# 16         SIC             6484285          7649391                    84.8
# 17         TOS             5588544          6156601                    90.8
# 18         UMB             1295623          1469397                    88.2
# 19         VDA              169998           191150                    88.9
# 20         VEN             7000178          8087568                    86.6
#
#    last_update NUTS1_code NUTS2_code  ISTAT_region_code  \
# 0   2021-10-11        ITF       ITF1                 13
# 1   2021-10-11        ITF       ITF5                 17
# 2   2021-10-11        ITF       ITF6                 18
# 3   2021-10-11        ITF       ITF3                 15
# 4   2021-10-11        ITH       ITH5                  8
# 5   2021-10-11        ITH       ITH4                  6
# 6   2021-10-11        ITI       ITI4                 12
# 7   2021-10-11        ITC       ITC3                  7
# 8   2021-10-11        ITC       ITC4                  3
# 9   2021-10-11        ITI       ITI3                 11
# 10  2021-10-11        ITF       ITF2                 14
# 11  2021-10-11        ITH       ITH1                  4
# 12  2021-10-11        ITH       ITH2                  4
# 13  2021-10-11        ITC       ITC1                  1
# 14  2021-10-11        ITF       ITF4                 16
# 15  2021-10-11        ITG       ITG2                 20
# 16  2021-10-11        ITG       ITG1                 19
# 17  2021-10-11        ITI       ITI1                  9
# 18  2021-10-11        ITI       ITI2                 10
# 19  2021-10-11        ITC       ITC2                  2
# 20  2021-10-11        ITH       ITH3                  5
#
#                                 region
# 0                              Abruzzo
# 1                           Basilicata
# 2                             Calabria
# 3                             Campania
# 4                       Emilia-Romagna
# 5                Friuli-Venezia Giulia
# 6                                Lazio
# 7                              Liguria
# 8                            Lombardia
# 9                               Marche
# 10                              Molise
# 11  Provincia Autonoma Bolzano / Bozen
# 12           Provincia Autonoma Trento
# 13                            Piemonte
# 14                              Puglia
# 15                            Sardegna
# 16                             Sicilia
# 17                             Toscana
# 18                              Umbria
# 19      Valle d'Aosta / Vallée d'Aoste
# 20                              Veneto

# %% [markdown]
# ## Teller Functions ("tell_")
#
# Teller functions are functions which return **the most interesting insights about the COVID-19 pandemic, many of which cannot be instantly worked out from the raw databases returned by Getter functions.** For example, get_vaccine_admin returns a DataFrame with plenty of data about COVID-19 vaccinations, but among them there is not the *total amount of people who have completed the vaccination cycle*: even though this is of great importance, the user would be forced to manually calculate this value with proper operations on the DataFrame, also taking into account requirements such as the fact that Janssen vaccine only requires one dose, as does every person who has been infected by SARS-CoV-2 before getting the vaccine. Teller functions do this for you, returning the end result (referring to the example, this is done by tell_total_vaccinated) and integrating Getter functions for those important values which, without the former, would be unjustifiably hard to get.

# %% [markdown]
# ### tell_manufacturer_delivered_doses(manufacturer)
#
# Returns the number of delivered vaccine doses from the manufacturer given as a parameter in Italy as an integer. If string "all" is provided as parameter, it returns the number of delivered vaccine doses from all manufacturers.
# ONLY ACCEPTED MANUFACTURERS AND SPELLINGS ARE "Pfizer/BioNTech", "Moderna", "Vaxzevria (AstraZeneca)" AND "Janssen". Strings other than manufacturer names or "all" yield an error.

# %%
icl.tell_manufacturer_delivered_doses("Pfizer/BioNTech")
# Out:
# 71088904

# %% [markdown]
# ### tell_total_admin_points
#
# Returns the number of all vaccine administration points in Italy as an integer.

# %%
icl.tell_total_admin_points()
# Out:
# 2903

# %% [markdown]
# ### tell_total_administered_doses
#
# Returns the amount of all administered doses ever in Italy as an integer.

# %%
icl.tell_total_administered_doses()
# Out:
# 86407784

# %% [markdown]
# ### tell_total_vaccinated(dose_number, option = "n")
#
# Depending on the integer value provided as *dose_number*:
# - dose_number = 1: returns the number of individuals who have been injected at least one vaccine dose in Italy (independently of it being enough for vaccination cycle completion, as is the case with Janssen vaccine or for individuals with recent COVID-19 injection, for whom only one dose is required);
# - dose_number = 2: returns the number of individuals who have completed the vaccination cycle in Italy (with double dose for Pfizer/BioNTech, Moderna and Vaxzevria (AstraZeneca), with single dose for Janssen, with single dose for individuals previously infected with COVID-19 between 3 and 6 months before vaccination);
# - dose_number = 3: returns the number of individuals who have been injected an extra dose of vaccine in Italy, being eligible for it depending on their medical condition (commonly referred to as "third dose" in media).
#
# Result is returned depending on the string value provided as *option*:
# - no option or option = "n" or "number": just returns the requested number as an integer (default option);
# - option = "o" or "over12": returns the requested number as a fraction of the Italian population aged over 12 (to which many official documents refer to) as a floating point;
# - option = "p" or "population": returns the requested number as a fraction of the whole Italian population as a floating point.
#
# **WARNING: function might take a while before returning!**
#
# The following example returns the total number of people who have completed the vaccination cycle:

# %%
icl.tell_total_vaccinated(2)
# Out:
# 43333605

# %% [markdown]
# This other example returns the percentage of individuals aged over 12 who have completed the vaccination cycle. This is a value usually quoted in media (since the official purpose of the vaccination campaign, as stated by Gen. Figliuolo, Extraordinary Commissioner for the COVID-19 emergency, is reaching 80% of over 12 individuals fully vaccinated by 30th September).

# %%
# returns a fraction, not a percentage
fraction_of_total_vaccinated = icl.tell_total_vaccinated(dose_number=2, option="over12")
percentage_of_total_vaccinated = fraction_of_total_vaccinated*100
print("{}%".format(percentage_of_total_vaccinated))
# Out:
# 80.23270585146972%

# %% [markdown]
# ## Grapher Functions
#
# Common Python libraries like Matplotlib provide an easy way for plotting data. However, this may become difficult when one wants to plot data on a map, since they would also need a complete description of political entities and borders. **Grapher functions make plotting on a map as easy as plotting a histogram.**
# NOTE: they are only guaranteed to work with Italian COVID Library generated DataFrames. Moreover, said DataFrames must have data referred to regions or provinces (depending if one aims at plotting on a map of regions or provinces).

# %% [markdown]
# ### plot_on_map(source, on, column, legend = True, cmap = "viridis")
#
# Plots data coming from column *column* of Italian COVID Library-generated DataFrame *source* on a map of Italy with regions or provinces, depending on the option *on* specified (options "region", "regions" or "r" for plotting on regions, options "province", "provinces" or "p" for provinces), displaying or not a legend (depending on option *legend*, default is *True*) and with the color palette *cmap* (color palettes are matplotlib ones, default is *viridis*).
#
# NOTE 1: DataFrame must contain regional or provincial data, only "getter" functions referred to regional or provincial phenomena return plotting-compatible DataFrames.
#
# NOTE 2: if you want to use the full customization power of libraries like GeoPandas, head to prepare_for_plotting_on_map.
#
# The following example plots the number of new COVID-19 cases per region on a map of Italian regions, displaying a legend and using the color palette *Reds*:

# %%
# gets the DataFrame with the data of our interest
cases_per_region = icl.get_region_cases_latest()
# new cases data is in the column "new_cases" of our DataFrame
cases_per_region_plot = icl.plot_on_map(source=cases_per_region, on="regions", column="new_cases", legend=True, cmap="Reds")

# %% [markdown]
# ### prepare_for_plotting_on_map(source, on)
#
# Makes Italian COVID Library-generated DataFrame *source* compatible with GeoPandas (i.e. a GeoDataFrame), for subsequent plotting on a map with Italian regions or provinces, depending on the option *on* specified (options "region", "regions" or "r" for plotting on regions, options "province", "provinces" or "p" for provinces). Use this function if you want to display your data on a map using the full potential of GeoPandas.
#
# NOTE: DataFrame must contain regional or provincial data, only "getter" functions referred to regional or provincial phenomena return potential GeoPandas-compatible DataFrames.
#
# The following example makes the DataFrame generated by get_region_cases_latest, containing the number of new COVID-19 cases per region, compatible with GeoPandas in order to subsequently plot these data on a map of Italian regions:

# %%
# gets the DataFrame with the data of our interest
cases_per_region = icl.get_region_cases_latest()
# prepare_for_plotting_on_map turns a Pandas DataFrame into a GeoPandas GeoDataFrame
cases_per_region_geopandas_compatible = icl.prepare_for_plotting_on_map(source=cases_per_region, on="regions")

# %% [markdown]
# We can now import GeoPandas and use it to plot data on a map of Italy with its regions. The following example in particular outputs the very same result as the example shown for the function plot_on_map: if you only need simple customization, head to plot_on_map which, given an Italian COVID Library-generated DataFrame, directly plots it on a map; prepare_for_plotting_on_map is better if you aim at more advanced customization using GeoPandas.

# %%
import geopandas
# below the function plot of GeoPandas is used
# new cases data is in the column "new_cases" of both the original DataFrame and its GeoPandas compatible version
cases_per_region_plot = cases_per_region_geopandas_compatible.plot(column="new_cases", legend=True, cmap="Reds")

# %% [markdown]
# ## Use examples of Italian COVID Library
#
# The following shows some practical use examples of Italian COVID Library functions.
#
# ### Plotting the trend of COVID-19 infections since the beginning of the pandemic
#
# In this example we shall see how to display a plot with the trend of COVID-19 infections (i.e. the number of new cases each day) from the first cases in February 2020.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# new cases per day are returned by get_national_trend
new_cases_trend = icl.get_national_trend()
plt.plot(new_cases_trend["date"], new_cases_trend["new_cases"])

# %% [markdown]
# The output is a graph with on the x axis the date and on the y axis the number of new cases diagnosed on that day. You can notice the four waves of the epidemic in correspondence of the peaks: the first one of Spring 2020, the second one in Autumn 2020, the third Alpha variant-induced one in Spring 2021 and the fourth Delta variant-induced one in late Summer 2021. Cases numbers are low during the first wave because of the poor and immature detection techniques used back then.

# %% [markdown]
# ### Getting and presenting the vaccination situation of individuals aged 50-59
#
# In this example we shall see how to evaluate the vaccination situation of individuals in their fifties. One of current (September-October 2021) issues of the pandemic is, in fact, the still high percentage of people aged between 50 and 59 who have not received any dose of the vaccine, posing a further obstacle on the so-yearned for return to normalcy. We also want to present the situation as a pie chart.

# %%
import matplotlib.pyplot as plt

# we need vaccine administration data
vaccine_admin = icl.get_vaccine_admin()
# we are only interested in data concerning people aged 50-59
vaccine_admin_50_59 = vaccine_admin[vaccine_admin["age_group"]=="50-59"]
# Janssen only requires one dose, so do previously infected individuals. Individuals given the 3rd dose are counted separately
fully_vaccinated_50_59 = vaccine_admin_50_59[vaccine_admin_50_59["manufacturer"]!="Janssen"].sum()["second_dose"]+vaccine_admin_50_59[vaccine_admin_50_59["manufacturer"]=="Janssen"].sum()["first_dose"]+vaccine_admin_50_59.sum()["previously_infected"]-vaccine_admin_50_59.sum()["extra_dose"]
extra_dose_vaccinated_50_59 = vaccine_admin_50_59.sum()["extra_dose"]
singly_vaccinated_50_59 = vaccine_admin_50_59.sum()["first_dose"]+vaccine_admin_50_59.sum()["previously_infected"]-fully_vaccinated_50_59-extra_dose_vaccinated_50_59
# we also need the amount of people to be vaccinated
eligible_data = icl.get_eligible()
# again, we are only interested in data concerning people aged 50-59
eligible_data_50_59 = eligible_data[eligible_data["age_group"]=="50-59"]
# sum is performed because data are returned separated per region
eligible_50_59 = eligible_data_50_59.sum()["population"]
non_vaccinated_50_59 = eligible_50_59-fully_vaccinated_50_59-extra_dose_vaccinated_50_59-singly_vaccinated_50_59
# we now have all the data we wanted
print("Fully vaccinated (excluding individuals given extra dose): {}".format(fully_vaccinated_50_59))
print("People also given extra dose: {}".format(extra_dose_vaccinated_50_59))
print("Singly vaccinated: {}".format(singly_vaccinated_50_59))
print("Non vaccinated: {}".format(non_vaccinated_50_59))
print("TOTAL: {}".format(eligible_50_59))

# we can now plot these data. Best way is through a pie chart
labels = "Fully, also given 3rd dose", "Fully", "Partially", "No injection"
# "sizes" requires percentages, calculated over amount of individuals eligible for vaccination
sizes = [extra_dose_vaccinated_50_59/eligible_50_59*100, fully_vaccinated_50_59/eligible_50_59*100, singly_vaccinated_50_59/eligible_50_59*100, non_vaccinated_50_59/eligible_50_59*100]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.show()
# Out:
# Fully vaccinated (excluding individuals given extra dose): 7830053
# People also given extra dose: 32839
# Singly vaccinated: 385922
# Non vaccinated: 1402727
# TOTAL: 9651541

# %% [markdown]
# We see (October 2021) that the vast majority of people aged 50-59 are vaccinated, but there is still a relevant group still to get their first dose. People in their fifties are indeed considered in danger of severe COVID, so that is why there being even such a relatively small percentage of non vaccinated individuals is risky.
